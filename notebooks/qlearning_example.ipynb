# %%
from micromazemaster.utils.qlearning import Qlearning
from micromazemaster.models.maze import Maze

maze = Maze(width=10, height=5, seed=1)

Q = Qlearning(maze=maze, start_position=(0.5, 0.5),goal_position=(9.5, 4.5))
plt, path = Q.run()
plt.show()
# Out:
# 2025-01-21 13:44:59.212 - [INFO] - New best path found in episode 1!
# 2025-01-21 13:44:59.213 - [INFO] - Path length: 918
# 2025-01-21 13:44:59.556 - [INFO] - New best path found in episode 5!
# 2025-01-21 13:44:59.557 - [INFO] - Path length: 772
# 2025-01-21 13:44:59.577 - [INFO] - New best path found in episode 6!
# 2025-01-21 13:44:59.578 - [INFO] - Path length: 440
# 2025-01-21 13:44:59.592 - [INFO] - New best path found in episode 7!
# 2025-01-21 13:44:59.592 - [INFO] - Path length: 436
# 2025-01-21 13:44:59.603 - [INFO] - New best path found in episode 8!
# 2025-01-21 13:44:59.604 - [INFO] - Path length: 387
# 2025-01-21 13:44:59.694 - [INFO] - New best path found in episode 11!
# 2025-01-21 13:44:59.695 - [INFO] - Path length: 345
# 2025-01-21 13:44:59.754 - [INFO] - New best path found in episode 14!
# 2025-01-21 13:44:59.755 - [INFO] - Path length: 235
# 2025-01-21 13:44:59.772 - [INFO] - New best path found in episode 16!
# ...
