# %%
from micromazemaster import Qlearning
from micromazemaster.models import Maze

maze = Maze(width=10, height=10, seed=1)

Q = Qlearning(maze=maze, start_position=(0.5, 0.5),goal_position=(5.5, 5.5))
plt, path = Q.run()
plt.show()
# Out:
# 2024-11-06 18:15:00.333 - [INFO] - [ Using Environment ]	 DEVELOPMENT
#     __  ____                 __  ___                 __  ___           __
#    /  |/  (_)_____________  /  |/  /___ _____  ___  /  |/  /___ ______/ /____  _____
#   / /|_/ / / ___/ ___/ __ \/ /|_/ / __ `/_  / / _ \/ /|_/ / __ `/ ___/ __/ _ \/ ___/
#  / /  / / / /__/ /  / /_/ / /  / / /_/ / / /_/  __/ /  / / /_/ (__  ) /_/  __/ /
# /_/  /_/_/\___/_/   \____/_/  /_/\__,_/ /___/\___/_/  /_/\__,_/____/\__/\___/_/
#
# 0.1.0
# New best path found in episode 1!
# Path length: 521
#
# New best path found in episode 4!
# Path length: 321
#
# New best path found in episode 8!
# Path length: 228
#
# New best path found in episode 13!
# Path length: 227
#
# New best path found in episode 14!
# Path length: 178
#
# New best path found in episode 16!
# Path length: 123
#
# New best path found in episode 19!
# Path length: 116
#
# New best path found in episode 25!
# Path length: 112
#
# New best path found in episode 26!
# Path length: 103
#
# New best path found in episode 27!
# Path length: 98
#
# New best path found in episode 28!
# Path length: 83
#
# New best path found in episode 29!
# Path length: 78
#
# New best path found in episode 32!
# Path length: 65
#
# New best path found in episode 35!
# Path length: 64
#
# New best path found in episode 40!
# Path length: 52
#
# New best path found in episode 54!
# Path length: 51
#
# New best path found in episode 68!
# Path length: 49
#
# New best path found in episode 70!
# Path length: 48
#
# New best path found in episode 76!
# Path length: 47
#
# New best path found in episode 91!
# Path length: 46
# Episode 100/100, Steps: 31, Total Reward: -1308.5, Epsilon: 0.271
# C:\Users\Luca\AppData\Local\Temp\ipykernel_14292\3540707693.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
