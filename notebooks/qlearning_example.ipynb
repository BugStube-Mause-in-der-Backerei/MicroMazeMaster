# %%
from micromazemaster.utils.qlearning import Qlearning
from micromazemaster.models.maze import Maze

maze = Maze(width=10, height=10, seed=1)

Q = Qlearning(maze=maze, start_position=(0.5, 0.5),goal_position=(5.5, 5.5))
plt, path = Q.run()
plt.show()
# Out:
# 2024-11-18 09:27:54.781 - [INFO] - [ Using Environment ]	 DEVELOPMENT
#     __  ____                 __  ___                 __  ___           __
#    /  |/  (_)_____________  /  |/  /___ _____  ___  /  |/  /___ ______/ /____  _____
#   / /|_/ / / ___/ ___/ __ \/ /|_/ / __ `/_  / / _ \/ /|_/ / __ `/ ___/ __/ _ \/ ___/
#  / /  / / / /__/ /  / /_/ / /  / / /_/ / / /_/  __/ /  / / /_/ (__  ) /_/  __/ /
# /_/  /_/_/\___/_/   \____/_/  /_/\__,_/ /___/\___/_/  /_/\__,_/____/\__/\___/_/
#
# 0.1.0
# 2024-11-18 09:27:55.213 - [INFO] - New best path found in episode 1!
# 2024-11-18 09:27:55.213 - [INFO] - Path length: 106
# 2024-11-18 09:27:55.310 - [INFO] - New best path found in episode 14!
# 2024-11-18 09:27:55.310 - [INFO] - Path length: 85
# 2024-11-18 09:27:55.339 - [INFO] - New best path found in episode 28!
# 2024-11-18 09:27:55.339 - [INFO] - Path length: 59
# 2024-11-18 09:27:55.339 - [INFO] - New best path found in episode 30!
# 2024-11-18 09:27:55.339 - [INFO] - Path length: 51
# ...
